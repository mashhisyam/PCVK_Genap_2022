# %% [markdown]
# <a href="https://colab.research.google.com/github/mashhisyam/PVCK_Genap_2022/blob/main/Week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('/content/drive/MyDrive/PCVK/j.png')

kernel = np.ones((5,5), np.uint8)
dilation = cv2.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f0061bfd7d0>,
# ...
#  Text(0.5, 1.0, 'Citra Dilasi'))

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv2.erode(img,kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(erosion),plt.title('Citra Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f9f6e207450>,
# ...
#  Text(0.5, 1.0, 'Citra Erosi'))

# %%
kernel = np.ones((5,5), np.uint8)
dilation = cv2.morphologyEx(img, cv2.MORPH_DILATE, kernel)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f0061b20810>,
# ...
#  Text(0.5, 1.0, 'Citra Dilasi'))

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(erosion),plt.title('Citra Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f0061b62c90>,
# ...
#  Text(0.5, 1.0, 'Citra Erosi'))

# %%
kernel = np.ones((7,7), np.uint8)
erosi = cv2.erode(img, kernel, iterations=1)
opening = cv2.dilate(erosi, kernel, iterations=1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(opening),plt.title('Citra Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f0061506710>,
# ...
#  Text(0.5, 1.0, 'Citra Opening'))

# %%
#Library
kernel = np.ones((7,7), np.uint8)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening), plt.title('Citra Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f0061452690>,
# ...
#  Text(0.5, 1.0, 'Citra Opening'))

# %%
kernel = np.ones((7,7), np.uint8)
dilasi = cv2.dilate(img, kernel, iterations=1)
closing = cv2.erode(dilasi, kernel, iterations=1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(closing),plt.title('Citra Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f006132aa90>,
# ...
#  Text(0.5, 1.0, 'Citra Closing'))

# %%
#library
kernel = np.ones((7,7), np.uint8)
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(closing), plt.title('Citra Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f006128b950>,
# ...
#  Text(0.5, 1.0, 'Citra Closing'))

# %%
#Dilasi dengan structuring elements cross 3 x 3
kernel_3x3 = cv2.getStructuringElement(cv2.MORPH_CROSS, (3,3))
crossDilation_3x3 = cv2.dilate(img, kernel_3x3, iterations = 1)

print('SED = Cross 3')
plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(crossDilation_3x3),plt.title('Citra Hasil Dilasi')
# Out:
# SED = Cross 3
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f0060c35790>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
kernel_5x5 = cv2.getStructuringElement(cv2.MORPH_CROSS, (5,5))
crossDilation_5x5 = cv2.dilate(img, kernel_5x5, iterations = 1)

print('SED = Cross 5')
plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(crossDilation_3x3),plt.title('Citra Hasil Dilasi')
# Out:
# SED = Cross 5
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f0060fbb350>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
kernel_3x3 = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3,3))
circleDilation_3x3 = cv2.dilate(img, kernel_3x3, iterations = 1)

print('SED = Circle 3')
plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(circleDilation_3x3),plt.title('Citra Hasil Dilasi')
# Out:
# SED = Circle 3
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f00614eb850>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
kernel_5x5 = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5,5))
circleDilation_5x5 = cv2.dilate(img, kernel_5x5, iterations = 1)

print('SED = Circle 5')
plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(circleDilation_5x5),plt.title('Citra Hasil Dilasi')
# Out:
# SED = Circle 5
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f0060c8d710>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
kernel_3x5 = cv2.getStructuringElement(cv2.MORPH_RECT, (3,5))
rectangleErosion_3x5 = cv2.erode(img, kernel_3x5, iterations = 1)

print('SED = Rectangle 3x5')
plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(rectangleErosion_3x5),plt.title('Citra Hasil Erosi')
# Out:
# SED = Rectangle 3x5
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f00607aeed0>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
kernel_5x7 = cv2.getStructuringElement(cv2.MORPH_RECT, (5,7))
rectangleErotion_5x7 = cv2.erode(img, kernel_5x7, iterations = 1)

print('SED = Rectangle 5x7')
plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(rectangleErotion_5x7),plt.title('Citra Hasil Erosi')
# Out:
# SED = Rectangle 5x7
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f00609703d0>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
kernelVertikal3 = np.ones((3,1), np.uint8)
erosionVertikal3 = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernelVertikal3)

print('SE = Line Vertikal 3')
plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(erosionVertikal3),plt.title('Citra Hasil Erosi')
# Out:
# SE = Line Vertikal 3
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f00600e0050>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
kernelVertikal5 = np.ones((5,1), np.uint8)
erosionVertikal5 = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernelVertikal5)

print('SE = Line Vertikal 5')
plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(erosionVertikal5),plt.title('Citra Hasil Erosi')
# Out:
# SE = Line Vertikal 5
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f0060050cd0>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))
